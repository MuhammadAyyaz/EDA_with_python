# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./data/oral_cancer_prediction_dataset.csv')

# %%
df.head()
# Out:
#    ID       Country  Age  Gender Tobacco Use Alcohol Consumption  \
# 0   1         Italy   36  Female         Yes                 Yes
# 1   2         Japan   64    Male         Yes                 Yes
# 2   3            UK   37  Female          No                 Yes
# 3   4     Sri Lanka   55    Male         Yes                 Yes
# 4   5  South Africa   68    Male          No                  No
#
#   HPV Infection Betel Quid Use Chronic Sun Exposure Poor Oral Hygiene  ...  \
# 0           Yes             No                   No               Yes  ...
# 1           Yes             No                  Yes               Yes  ...
# 2            No             No                  Yes               Yes  ...
# 3            No            Yes                   No               Yes  ...
# 4            No             No                   No               Yes  ...
#
#   Difficulty Swallowing White or Red Patches in Mouth Tumor Size (cm)  \
# ...

# %%
(df.isnull().sum() * 100) / len(df['ID'])
# Out:
# ID                                          0.0
# Country                                     0.0
# Age                                         0.0
# Gender                                      0.0
# Tobacco Use                                 0.0
# Alcohol Consumption                         0.0
# HPV Infection                               0.0
# Betel Quid Use                              0.0
# Chronic Sun Exposure                        0.0
# Poor Oral Hygiene                           0.0
# Diet (Fruits & Vegetables Intake)           0.0
# Family History of Cancer                    0.0
# Compromised Immune System                   0.0
# Oral Lesions                                0.0
# Unexplained Bleeding                        0.0
# Difficulty Swallowing                       0.0
# White or Red Patches in Mouth               0.0
# Tumor Size (cm)                             0.0
# Cancer Stage                                0.0
# Treatment Type                              0.0
# ...

# %%
df['Country'].unique()
# Out:
# array(['Italy', 'Japan', 'UK', 'Sri Lanka', 'South Africa', 'Taiwan',
#        'USA', 'Germany', 'France', 'Australia', 'Brazil', 'Pakistan',
#        'Kenya', 'Russia', 'Nigeria', 'Egypt', 'India'], dtype=object)

# %%
pk_df = df[df["Country"] == 'Pakistan']

# %%
specs= pk_df[(pk_df['Betel Quid Use']=='Yes') & (pk_df['Oral Cancer (Diagnosis)']=='Yes') & (pk_df['Oral Lesions']=='Yes')]
survived = specs[specs['Survival Rate (5-Year, %)']>80]
died = specs[specs['Survival Rate (5-Year, %)']<80]

# %%
died
# Out:
#           ID   Country  Age  Gender Tobacco Use Alcohol Consumption  \
# 73        74  Pakistan   60    Male          No                  No
# 1066    1067  Pakistan   34    Male         Yes                  No
# 1091    1092  Pakistan   56  Female          No                 Yes
# 1195    1196  Pakistan   69    Male         Yes                 Yes
# 1474    1475  Pakistan   62  Female         Yes                 Yes
# ...      ...       ...  ...     ...         ...                 ...
# 84523  84524  Pakistan   55    Male         Yes                 Yes
# 84544  84545  Pakistan   70  Female         Yes                 Yes
# 84649  84650  Pakistan   62    Male         Yes                  No
# 84711  84712  Pakistan   28    Male          No                 Yes
# 84766  84767  Pakistan   56    Male         Yes                 Yes
#
#       HPV Infection Betel Quid Use Chronic Sun Exposure Poor Oral Hygiene  \
# 73              Yes            Yes                  Yes                No
# ...

# %%
died[died['Alcohol Consumption']=='Yes']
# Out:
#           ID   Country  Age  Gender Tobacco Use Alcohol Consumption  \
# 1091    1092  Pakistan   56  Female          No                 Yes
# 1195    1196  Pakistan   69    Male         Yes                 Yes
# 1474    1475  Pakistan   62  Female         Yes                 Yes
# 2179    2180  Pakistan   54    Male         Yes                 Yes
# 2246    2247  Pakistan   41    Male         Yes                 Yes
# ...      ...       ...  ...     ...         ...                 ...
# 83953  83954  Pakistan   43    Male         Yes                 Yes
# 84523  84524  Pakistan   55    Male         Yes                 Yes
# 84544  84545  Pakistan   70  Female         Yes                 Yes
# 84711  84712  Pakistan   28    Male          No                 Yes
# 84766  84767  Pakistan   56    Male         Yes                 Yes
#
#       HPV Infection Betel Quid Use Chronic Sun Exposure Poor Oral Hygiene  \
# 1091             No            Yes                  Yes                No
# ...
